# %%
def merge_sorted_lists(list1, list2):
    result = []
    i = 0
    j = 0

    while i < len(list1) and j < len(list2):
        if list1[i] <= list2[j]:
            result.append(list1[i])
            i += 1
        else:
            result.append(list2[j])
            j += 1

    result.extend(list1[i:])
    result.extend(list2[j:])

    return result

with open("input2(1).txt", "r") as input_file:
    N = int(input_file.readline())
    list1 = list(map(int, input_file.readline().split()))
    M = int(input_file.readline())
    list2 = list(map(int, input_file.readline().split()))

merged_list = merge_sorted_lists(list1, list2)

with open("output2(1).txt", "w") as output_file:
    output_file.write(" ".join(map(str, merged_list)) + "\n")
